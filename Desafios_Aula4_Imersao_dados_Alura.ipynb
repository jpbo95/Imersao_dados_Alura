# %% [markdown]
# <a href="https://colab.research.google.com/github/jpbo95/Imersao_dados_Alura/blob/main/Desafios_Aula4_Imersao_dados_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imersão Dados Alura - 3ª edição**
#
# Este notebook contem as analises e resultados dos desafios propostos durante as aulas da imersão. #imersaodados #alura

# %% [markdown]
# #**Aula 1**
# Análise de dados, python, pandas e novos fármacos

# %% [markdown]
# **Importações inicias**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set()

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# **Analise Inicial dos dados**

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #Mostra os dois tipos de tratamentos (com droga e com controle)
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique() #Mostra os três periodos de tempos de tratamento (24, 48 e 72 horas)
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique() #Mostra que existe 2 tipos de doses
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts() #Mostra a quantidade de cada tratamento
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts() #Mostra a quantidade de cada dose
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 01: Investigar porque a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 ultimas linhas da tabela.
#
# ###Desafio 03: Proporção das classes tratamento.
#
# ###Desafio 04: Quantos tipos de drogas foram investigados.
#
# ###Desafio 05: Procurar na documentação o metodo query (Pandas).
#
# ###Desafio 06: Renomear as colunas tirando o hifen.
#
# ###Desafio 07: Deixar os graficos bonitos. (Matplotlib.pyplot)
#
# ###Desafio 08: Resumo do que aprendeu com os dados

# %% [markdown]
# ##Desafio 01: Investigar porque a classe tratamento é tão desbalanceada?

# %%
dados.query('tratamento == "com_controle"') #filtro que mostra apenas o tratamento com controle
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %% [markdown]
# Foi realizado uma filtragem utilizando o comando query e identificamos que na coluna droga apresenta apenas o valor "cacb2b860". Podemos considerar que nesses casos outras drogas não seriam eficientes e foi utilizado a droga "cacb2b860" para ter tal informação, portanto, o tratamento com controle se mostrou mais eficaz.

# %% [markdown]
# ##Desafio 02: Plotar as 5 ultimas linhas da tabela.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize = True)*100 #mostra a porcentagem de cada tratamento (Com droga 92,16% e com tratamento 7,83%)
# Out:
# com_droga       92.164273
# com_controle     7.835727
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)*100 #mostra a porcentagem de cada dose (D1 51,01% e D2 48,99%)
# Out:
# D1    51.007811
# D2    48.992189
# Name: dose, dtype: float64

# %% [markdown]
# ##Desafio 04: Quantos tipos de drogas foram investigados.

# %%
dados['droga'].value_counts() #Mostra que existem 3289 tipos de drogas
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 82dcdb180       1
# b2fe3eca7       1
# 4d7280c91       1
# 209a68d23       1
# 8bc88a3be       1
# Name: droga, Length: 3289, dtype: int64

# %%
dados['droga'].unique() #Mostra o array de drogas
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# ##Desafio 05: Procurar na documentação o metodo query (Pandas).Procurar na documentação o metodo query

# %%
new_dados = dados.copy()
new_dados.columns =[column.replace("-", "") for column in new_dados.columns]
new_dados.query('g0 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# Utilizando query para filtrar as informações

# %% [markdown]
# ##Desafio 06: Renomear as colunas tirando o hifen.

# %%
new_dados = dados.copy()
new_dados.columns =[column.replace("-", "") for column in new_dados.columns]
new_dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ##Desafio 07: Deixar os graficos bonitos. (Matplotlib.pyplot)

# %%
dados['tratamento'].value_counts().plot.pie()
plt.title('Formas de Tratamento')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dados['tempo'].value_counts().plot.pie()
plt.title('Tempo do Tratamento')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dados['tempo'].value_counts().plot.bar()
plt.title('Tempo de tratamento')
plt.ylabel('Quantidade')
plt.xlabel('Tempo')
plt.show()

# %% [markdown]
# ##Desafio 08: Resumo do que aprendeu com os dados

# %% [markdown]
# Analisando este caso, encontramos a droga "cacb2b860", fazendo que tivessemos uma breve noção do porque o tratamento é efetuado com controle.
# Foi possivel aprender como a tecnologia facilita diversas areas. O experimento contem diversas informações mais mesmo assim, com a ajuda do pandas, conseguimos indentificar comportamentos e proporções.

# %% [markdown]
# #**Aula 2**
# Estatísticas, visualização de dados e distribuições

# %% [markdown]
# ##informações absorvidas na aula

# %%
mapa = {'droga' : 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
plt.figure(figsize=(8, 6))

ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100)

# %%
dados['g-19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g-0', 'g-1']]
# Out:
#           g-0     g-1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins = 30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins = 30)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['max'].hist(bins = 30)

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins = 50)

# %%
sns.boxplot(x='g-0', data=dados)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(y='g-0', x= 'tratamento', data=dados)

# %% [markdown]
# ###Desafio 01: Ordenar o grafico com countplot do menor para o maior
#
# ###Desafio 02: Melhorar a visualização do grafico, alterando tamanho da fonte.
#
# ###Desafio 03: Plotar os histogramas com seaborn.
#
# ###Desafio 04: Estudar sobre as estatisticas retornadas no .describe()
#
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações
#
# ###Desafio 06: Fazer outras analises com o boxplot e até com o histograma, plotando mais de um na mesma celula
#
# ###Desafio 07: Resumo do que aprendeu com os dados

# %% [markdown]
# ##Resolução dos desafios

# %% [markdown]
# ###Desafio 01: Ordenar o grafico com countplot do menor ao maior

# %%
cod_compostos = dados['composto'].value_counts().index[5:0:-1]
plt.figure(figsize=(8, 6))

ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order= cod_compostos, palette='pastel')
ax.set_title('Top 5 compostos')
ax.set_ylabel('Quantidade')
plt.show()

# %% [markdown]
# ###Desafio 02: Melhorar a visualização do grafico, alterando tamanho da fonte.

# %%
plt.figure(figsize=(10, 7))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'), order= cod_compostos, palette='pastel')
ax.set_title('Top 5 compostos', fontsize= 15, color='darkblue')
ax.set_ylabel('Quantidade', fontsize= 15, color='darkblue')
ax.set_xlabel('Compostos', fontsize= 15, color='darkblue')
plt.show()

# %% [markdown]
# ###Desafio 03: Plotar os histogramas com seaborn.

# %%
plt.figure(figsize=(8, 6))
hist = dados.loc[:,'g-0':'g-771'].describe().T['mean']
ax = sns.histplot(data= hist, bins=100)
ax.set_title('Histograma', fontsize=15)
ax.set_ylabel('Quantidade', fontsize=15)
ax.set_xlabel('Dados', fontsize=15)
plt.show()

# %% [markdown]
# ###Desafio 04: Estudar sobre as estatisticas retornadas no .describe()

# %%
dados.loc[:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# **count =** Quantidade de valores ou linhas
#
# **mean =** Média aritmética da amostra
#
# **std =** Desvio padrão entorno da média
#
# **min =** Valor minimo da amostra
#
# **25%, 50%, 75% =** Demonstração da forma de distribuição da amostra
#
# **max =** Valor maximo da amostra

# %% [markdown]
# ###Desafio 05: Refletir sobre a manipulação do tamanho das visualizações

# %% [markdown]
# Concluímos que a visualização gráfica depende do tipo e tamanho dos dados que estamos estudando.Também podemos pensar que em alguns casos, o gráfico pode ficar melhor apresentado de uma maneira enxuta, mas em outros casos não.
# Cabe a nós avaliarmos qual é a melhor solução.

# %% [markdown]
# ###Desafio 06: Fazer outras analises com o boxplot e até com o histograma, plotando mais de um na mesma celula

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8), sharey=True)

# Tratamento
sns.boxplot(ax=axes[0], y='g-0', x='tratamento' , data=dados)
axes[0].set_title('Análise tratamento', fontsize=15)
axes[0].set_xlabel('Tipos de Tratamentos',fontsize=12)
axes[0].set_ylabel('Valores G-0',fontsize=12)

# Tempo
sns.boxplot(ax=axes[1], y='g-0', x='tempo' , data=dados)
axes[1].set_title('Análise tempo', fontsize=15)
axes[1].set_xlabel('Tempo',fontsize=12)
axes[1].set_ylabel('Valores G-0',fontsize=12)
# Out:
# Text(0, 0.5, 'Valores G-0')

# %% [markdown]
# ###Desafio 07: Resumo do que aprendeu com os dados

# %% [markdown]
# Com esta aula conseguimos aprender a como encontrar melhores formas de realizar analises com graficos, melhorando a visualização para melhor compreenção dos dados

# %% [markdown]
# #Aula 3
#
# Correlações, casualidade e relações entre genes.

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize= 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values= dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
sns.scatterplot(x='g-0', y='g-8', data=dados)

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'})

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color': 'red'}, col='tratamento', row= 'tempo')

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
corr = dados.loc[:,'g-0':'g-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ###Desafio 1: Criar tabelas de frequencia com pandas.groupby()
#
# ###Desafio 2: Normalizar o crosstab pela coluna
#
# ###Desafio 3: Explorar outros agregadores
#
# ###Desafio 4: Explorar o melt.
#
# ###Desafio 5: Calcular e analizar a correlação entre G e C. Refletir sobre os efeitos biologicos.
#
# ###Desafio 6: Estudar o codigo que plota a matrix de correlação (heatmap)
#
# ###Desafio 7: Resumo dos que aprendeu com os dados.

# %% [markdown]
# ##Resultados

# %% [markdown]
# ###Desafio 1: Criar tabelas de frequencia com pandas.groupby()

# %%
freq = dados.groupby(['dose', 'tempo', 'tratamento']).size().unstack(2)
freq
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# ###Desafio 2: Normalizar o crosstab pela coluna

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 1)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ###Desafio 3: Explorar outros agregadores

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values= dados['g-0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %% [markdown]
# ###Desafio 4: Explorar o melt.

# %%
melt = pd.melt(dados, id_vars = ['tratamento', 'dose'], value_vars = 'g_0').head(10)
melt
# Out:
#   tratamento dose variable   value
# 0  com_droga   D1     c-99  0.4176
# 1  com_droga   D1     c-99  0.7371
# 2  com_droga   D1     c-99  0.6931
# 3  com_droga   D1     c-99 -0.8154
# 4  com_droga   D2     c-99  0.7125
# 5  com_droga   D1     c-99  1.3990
# 6  com_droga   D2     c-99 -0.3179
# 7  com_droga   D1     c-99  0.0260
# 8  com_droga   D1     c-99  0.5543
# 9  com_droga   D2     c-99 -2.0000

# %% [markdown]
# ###Desafio 5: Calcular e analizar a correlação entre G e C. Refletir sobre os efeitos biologicos.

# %%
c = dados.loc[ :, 'c-0' : 'c-5']
g = dados.loc[ :, 'g-0' : 'g-5']
corr_c_g = pd.concat([c, g], axis = 1).corr()

plt.figure(figsize = (14, 8))
plt.title("Correlação entre C-0 | C-5 e G-0 | G-5")

sns.heatmap(corr_c_g, annot = True)

plt.show()

# %% [markdown]
# ###Desafio 6: Estudar o codigo que plota a matrix de correlação (heatmap)

# %%
plt.figure(figsize = (14, 8))
sns.heatmap(corr_c_g, annot = True)

# %% [markdown]
# ###Desafio 7: Resumo dos que aprendeu com os dados.

# %% [markdown]
# Aprendemos mais sobre correlação de dados, usando funções para manipulação e visualização desses dados para facilitar futuras analises

# %% [markdown]
# #Aula 4
#
# Merge de dados e análise de resultados

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.sum()
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# ...

# %%
dados_resultados.drop('id', axis=1).sum(axis= 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis= 1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on= 'id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize= (18, 8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y= 'g-0', x= 'composto', hue= 'ativo_moa')

# %% [markdown]
# ###Desafio 01: Encontrar o top 10 das ações do Moa (inibidor, agonista...)
#
# ###Desafio 02: Criar a coluna eh_contole para quando na linha tratamento == com_controle
#
# ###Desafio 03: Criar 3 colunas para indicar o tempo 24, 48, 72
#
# ###Desafio 04: Estudar sobre combinações de data frames
#
# ###Desafio 05: Fazer analise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolhendo uma droga e comparando com o controle)
#
# ###Desafio 06: Descobrir se tempo algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA
#
# ###Desafios 07: Descobrir se tempo algum composto que dependendo da configuração do experimento, ativa MOAs diferentes
#
# ###Desafio 08: Resumo dos que aprendeu com os dados.

# %% [markdown]
# ##Resultados

# %% [markdown]
# ###Desafio 01: Encontrar o top 10 das ações do Moa (inibidor, agonista...)

# %%
moa = dados_resultados.columns

df_moa = pd.DataFrame(moa)

i, n = 1, 6
while i < n:
  df_moa = df_moa.replace(r'^.*?_','', regex=True)
  i += 1

top_moa = df_moa.value_counts()[:10]
top_moa
# Out:
# inhibitor         112
# antagonist         32
# agonist            28
# activator           5
# agent               3
# moa                 2
# blocker             2
# anticonvulsant      1
# antihistamine       1
# antifungal          1
# dtype: int64

# %% [markdown]
# ###Desafio 02: Criar a coluna eh_contole para quando na linha tratamento == com_controle

# %%
dados_combinados['eh_controle'] = dados_combinados['tratamento'] == 'com_controle'
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %% [markdown]
# ###Desafio 03: Criar 3 colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['tempo_24'] = dados_combinados['tempo'] == 24
dados_combinados['tempo_48'] = dados_combinados['tempo'] == 48
dados_combinados['tempo_72'] = dados_combinados['tempo'] == 72

dados_combinados.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...     True    False     False
# 1  id_000779bfc  com_droga     72  ...    False    False      True
# 2  id_000a6266a  com_droga     48  ...    False     True     False
# 3  id_0015fd391  com_droga     48  ...    False     True     False
# 4  id_001626bd3  com_droga     72  ...    False    False      True
#
# [5 rows x 883 columns]

# %% [markdown]
# ###Desafio 04: Estudar sobre combinações de data frames

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ###Desafio 05: Fazer analise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolhendo uma droga e comparando com o controle)

# %%
dados_combinados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 82dcdb180       1
# b2fe3eca7       1
# 4d7280c91       1
# 209a68d23       1
# 8bc88a3be       1
# Name: composto, Length: 3289, dtype: int64

# %%
composto = dados_combinados[dados_combinados['composto']=='87d714366']
controle = dados_combinados[dados_combinados['tratamento']=='com_controle']


fig, axs = plt.subplots(1,2,figsize=(20,8))

sns.boxplot(data=composto,y='g-0', x='tempo', hue='dose',ax=axs[0])
axs[0].set_title('Composto 87d714366')
sns.boxplot(data=controle,y='g-0', x='tempo', hue='dose',ax=axs[1])
axs[1].set_title('Controle 87d714366')
# Out:
# Text(0.5, 1.0, 'Controle 87d714366')

# %% [markdown]
# ###Desafio 06: Descobrir se tem algum composto dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
dados_combinados[['composto','ativo_moa']].query('ativo_moa == True')
# Out:
#         composto  ativo_moa
# 0      b68db1d53       True
# 2      18bb41b2c       True
# 4      7cbed3131       True
# 5      e06749542       True
# 7      8b87a7a83       True
# ...          ...        ...
# 23807  a28556d51       True
# 23808  6c3a459be       True
# 23809  df1d0a5a1       True
# 23810  ecf3b6b74       True
# 23812  8b87a7a83       True
#
# [14447 rows x 2 columns]

# %%
dados_combinados[['composto','ativo_moa']].query('ativo_moa == False')
# Out:
#         composto  ativo_moa
# 1      df89a8e5a      False
# 3      8c7f86626      False
# 6      746ca1f5a      False
# 8      952b76dfc      False
# 14     e0cd5c091      False
# ...          ...        ...
# 23801  24c787f29      False
# 23804  74515bfd2      False
# 23806  47dd8f190      False
# 23811  cacb2b860      False
# 23813  972f41291      False
#
# [9367 rows x 2 columns]

# %% [markdown]
# ###Desafios 07: Descobrir se tempo algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %%
diferente_n_moa = dados_combinados.groupby(['composto'])['n_moa'].nunique().reset_index()
diferente_n_moa.sort_values('n_moa', ascending=False)
# Out:
#        composto  n_moa
# 0     00199ff52      1
# 2197  b0b0fec1d      1
# 2187  afafe3ca9      1
# 2188  afd0dbace      1
# 2189  afed0fc6d      1
# ...         ...    ...
# 1099  5aa46f542      1
# 1100  5ab0bda1e      1
# 1101  5ab704064      1
# 1102  5ac378d8a      1
# 3288  fff7d208d      1
#
# [3289 rows x 2 columns]

# %% [markdown]
# ###Desafio 08: Resumo dos que aprendeu com os dados.

# %% [markdown]
# Aprendemos a mesclar dados, colocando colunas para uma melhor analise.
